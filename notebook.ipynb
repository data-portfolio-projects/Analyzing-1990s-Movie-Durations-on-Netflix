# %% [markdown]
# # **Introduction**
# - Netflix, launched in 1997 as a DVD rental service, has evolved into a leading entertainment and media company.
# - This project explores Netflix's movie catalog, focusing on films from the 1990s.
#
# # **Purpose**
# - Perform exploratory data analysis (EDA) on Netflix's 1990s movie catalog.
# - Provide insights for a production company specializing in nostalgic styles.
#
# # **Analysis of the Netflix Movie Catalog**
# - Examine genre distribution, release patterns, and popularity of 1990s movies.
# - Identify key trends and audience preferences from the 1990s.
#
# # **Contextual Information**
# - Rising interest in nostalgic content on streaming platforms.
# - Guide production company’s future projects and strategies with data insights.
#
# # **Increase in Popularity of Nostalgic Content**
# - Analyze factors contributing to the popularity of 1990s movies.
# - Understand which genres and themes resonate with audiences.
#
# # **Question of Analysis**
# - What are the key characteristics and trends of 1990s movies available on Netflix?
#
# # **Factors Affecting Popularity and Audience Preferences**
# - Identify factors influencing the popularity of 1990s movies.
# - Tailor production projects to meet audience expectations based on data insights.

# %% [markdown]
# # **Data**
#
# ## **Description and Tables**
# The dataset netflix_data.csv provides detailed information about movies available on Netflix. Below is a table outlining the columns and their descriptions:
#
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %% [markdown]
# ## **Methods**
#
# ### **Data Preparation and Analysis**
# - Import Libraries: Import pandas and matplotlib for data manipulation and visualization.
# - Load Data: Read the Netflix CSV file into a DataFrame.
# - Data Cleaning: Ensure the 'duration' column is in the correct format by removing ' min' and converting to integer.
# - Filter Data: Filter the DataFrame for movies released in the 1990s.
# - Calculate Mode: Determine the most frequent movie duration in the 1990s.
# - Filter Specific Movies: Count the number of short action movies (duration < 90 minutes) released in the 1990s.

# %% [markdown]
# ## **Code Implementation**

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %%
# Check the first few rows of the dataset to understand its structure
print(netflix_df.head())
# Out:
#   show_id  ...             genre
# 0      s2  ...            Dramas
# 1      s3  ...     Horror Movies
# 2      s4  ...            Action
# 3      s5  ...            Dramas
# 4      s6  ...  International TV
#
# [5 rows x 11 columns]

# %%
# Ensure the 'duration' column is in the correct format
# Remove ' min' from the 'duration' column and convert to integer

# Convert the 'duration' column to string first to avoid the AttributeError
netflix_df['duration'] = netflix_df['duration'].astype(str).str.replace(' min', '', regex=False).astype(int)

# %%
# Filter for movies released in the 1990s
movies_1990s = netflix_df[(netflix_df['release_year'] >= 1990) & 
                          (netflix_df['release_year'] < 2000) & 
                          (netflix_df['type'] == 'Movie')]

# %%
# What was the most frequent movie duration in the 1990s?
most_frequent_duration = movies_1990s['duration'].mode()[0]
duration = int(most_frequent_duration)

# %%
# Count the number of short action movies released in the 1990s
short_action_movies = movies_1990s[(movies_1990s['duration'] < 90) & 
                                    (movies_1990s['genre'].str.contains('Action', case=False, na=False))]

# %%
short_movie_count = short_action_movies.shape[0]

# %%
# Print the results
print(f'The most frequent movie duration in the 1990s is: {duration} minutes')
print(f'The number of short action movies released in the 1990s is: {short_movie_count}')
# Out:
# The most frequent movie duration in the 1990s is: 94 minutes
# The number of short action movies released in the 1990s is: 7

# %%
# Optional: Visualization of movie durations from the 1990s
plt.figure(figsize=(12, 6))
plt.hist(movies_1990s['duration'], bins=30, color='blue', alpha=0.7)
plt.axvline(x=duration, color='red', linestyle='dashed', linewidth=2, label=f'Most Frequent Duration: {duration} min')
plt.title('Distribution of Movie Durations in the 1990s')
plt.xlabel('Duration (minutes)')
plt.ylabel('Number of Movies')
plt.legend()
plt.show()

# %% [markdown]
# ## **Analysis of the Histogram**
#
# **Distribution Shape:**
#
# - Approximately normal, with a noticeable central tendency.
# - Bell-like curve but not perfect.
#
# **Central Tendency:**
#
# - Peak at around 94 minutes (highlighted by the red dashed line).
# - Significant portion of movies clustered around this duration.
#
# **Range of Durations:**
#
# - Durations range from approximately 25 to almost 200 minutes.
#
# **Spread:**
#
# - Fewer movies at extreme ends (both very short and very long).
# - Most movies followed a typical length.
#
# **Skewness:**
#
# - Slight right skew.
# - More films with longer runtimes than very short ones.
#
# **Modality:**
#
# - Unimodal distribution (one clear peak).
# - Concentrated in one general range, no multiple common length ranges.
#
# ## **Actionable Insights**
#
# **Standard Duration in 1990s:**
#
# - Film duration close to 94 minutes can be considered "standard".
# - Useful for trend analysis on duration changes over years.
#
# **Content Strategy:**
#
# - 94-minute duration might indicate audience preference in the 1990s.
# - Suggests film duration wasn’t heavily segmented across genres.
#
# **Comparison Across Time Periods:**
#
# - Compare distributions of film durat ions across decades.
# - Visualize and measure differences in film length standards.
#
# **Potential for Segmentation:**
#
# - Analyze if certain genres tend to shorter or longer durations.
# - Useful for current film production landscape.
#
# **Data Cleaning:**
#
# - Visualization hints at potential data entry errors, especially for very small durations.
# - Indicates a need for improvements in data collection and cleaning pipelines.

# %% [markdown]
# ## **Results**
#
# **Description and Visuals**
#
# - Most Frequent Movie Duration: The most frequent movie duration in the 1990s is 94 minutes.
# - Short Action Movies: There are 7 short action movies (duration < 90 minutes) released in the 1990s.

# %% [markdown]
# The most frequent movie duration in the 1990s is: 94 minutes
# The number of short action movies released in the 1990s is: 7

# %% [markdown]
# **Histogram Visualization**
#
# - The histogram of movie durations from the 1990s shows a clear central tendency around 94 minutes, with fewer movies at the extreme ends of the duration range.
# - The right-skewed, unimodal distribution provides insights into the typical movie length during that decade, helping us understand audience preferences and potential trends in movie production.
